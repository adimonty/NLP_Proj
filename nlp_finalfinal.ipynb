# %% [markdown]
# <a href="https://colab.research.google.com/github/adimonty/NLP_Proj/blob/main/nlp_finalfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
------------------------------------------------------------------------------------------
->  beer_similarity.py
Calculate how semantically homogenous text reviews becomome for a corpus that
contains beer reviews.
------------------------------------------------------------------------------------------
Author : Aditya Mohanty
"""
# %%
# load required libraries
# !pip install sentence_transformers
import json
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim
from datetime import datetime
 
# global list that will hold the corpus data
product_reviews = []
 
# %%
# a function that normalizes the corpus data we provide and load it into our global list
 
def parseProductReviews(input):
    global product_reviews
 
    with open(input) as file:
        product_reviews = json.load(file)
 
    for review in product_reviews[:]:
        if not review["text"]:
            # remove review that contains no text
            product_reviews.remove(review)
        else:
            try:
                testDateFormat = bool(datetime.strptime(review["date"], '%b %d, %Y'))
            except:
                # remove review that is in the incorrect date format
                product_reviews.remove(review)
 
    # sort the reviews by date ascending
    product_reviews = sorted(product_reviews, key=lambda x: datetime.strptime(x['date'], '%b %d, %Y'))
 
# %%
# a function that calculates embeddings for a specific beer
# the embeddings are saved as a .csv file
 
def calculateReviewEmbeddings(data, beer, doHeatmap):
    embeddings = None
    sentences = []
 
    # add all sentences for the specified beer to a list
    for i in range(len(data)):
        if data[i]["beer"] == beer:
            sentences.append(data[i]["text"])
 
    # load a pre-trained model to generate the embeddings
    model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
    embeddings = model.encode(sentences, show_progress_bar=True)
    print("[{}] Number of sentence embeddings and number of values: {}".format(beer, embeddings.shape))
 
    # create a new array and load our embeddings into it
    sim = np.zeros((len(embeddings), len(embeddings)))
    for i in range(len(sentences)):
        sim[i:, i] = cos_sim(embeddings[i], embeddings[i:]) 
 
    # save our calculated embeddings into a csv file
    np.savetxt("{}-embeddings.csv".format(beer), sim, delimiter=",")
    print(sim)
    if doHeatmap == True:
        createHeatmap(sim, "Heatmap - {} (Similarity between review text)".format(beer))
 
# %%
# a function that loads embeddings for a specific beer from a .csv file
 
def calculateReviewEmbeddingFromCsv(data, beer, file, doHeatmap):
    embeddings = []
    sentences = []
 
    embeddings = np.loadtxt(file, delimiter=",")
    for sentence in data:
        if sentence["beer"] == beer:
            sentences.append(sentence["text"])
 
    # for sentence, embedding in zip(sentences, embeddings):
    #     print("\n Sentence: {} \n".format(sentence))
    #     print("\n Embedding: {} \n".format(embedding))
    # print(len(sentences))
    # print(len(embeddings))
 
    # create a new array and load our embeddings into it
    sim = np.zeros((len(embeddings), len(embeddings)))
    for i in range(len(sentences)):
        sim[i] = embeddings[i]
 
    # round the embeddings to one decimal places
    sim = np.round(sim, 1)
    print(sim)
 
    if doHeatmap == True:
        createHeatmap(sim, "{} - Similarity between review text".format(beer))
 
# %%
# a function that draws a heatmap
def createHeatmap(array, title):
    # create a heatmap based on the embeddings
    ax = sns.heatmap(array, cmap="coolwarm", linewidth=0.5, annot=True)
    ax.set_title(title)
    plt.show()
 
# %%
# a function that plots an annotated line graph from a .csv file which contains embeddings
 
def plotLineGraph(data, beer, file):
    embeddings = []
    dates = []
    csv_embeddings = np.loadtxt(file, delimiter=",")
 
    for review in data:
        if review["beer"] == beer:
            dates.append(review["date"])
 
    # remove the first embedding since it equals to 1
    dates.pop(0)
 
    # load .csv data into a list
    row = 0
    for i in range(1, len(csv_embeddings)):
        embeddings.append(csv_embeddings[i][row])
        row += 1
 
    # round the embeddings to two decimal places
    embeddings = np.round(embeddings, 2)
 
    # draw line graph
    fig, ax = plt.subplots()
    plt.plot(dates, embeddings)
    plt.xlabel("Date of review", size=12)
    plt.ylabel("Similarity", size=12)
    plt.title("Change in text similarity between review text for {}".format(beer), size=15)
    # create text annotations for data points
    for i in range(len(dates)):
        ax.text(dates[i], embeddings[i], embeddings[i], size=12)
    plt.xticks(rotation=90)
    plt.grid()
    plt.show()
 
# %%
# a function that generates embeddings for all reviews depending on the beer name
# the embeddings are saved in a seperate .csv file per beer
 
def generateAllEmbeddings(data):
    beer_names = []
 
    # make a list of all individual beers that exist in the corpus
    for review in data:
        if review["beer"] not in beer_names:
            beer_names.append(review["beer"])
            print(review["beer"])
    print("Total number of beer's found: {}".format(len(beer_names)))
 
    # calculate and save embedding in a .csv file for each beer
    for beer in beer_names:
        calculateReviewEmbeddings(product_reviews, beer, False)
 
# %%
# a function that calculates the mean for the first 10 percent of y values and the mean of
# all the y values. The result is used to show the trend.
 
def calculateMean(data):
    beer_names = []
    for review in data:
        if review["beer"] not in beer_names:
            beer_names.append(review["beer"])
            print(review["beer"])
    print("Total number of beer's found: {}".format(len(beer_names)))
 
    y_mean_all = []
    for beer in beer_names:
        embeddings = []
        dates = []
        csv_embeddings = None
        for review in data:
            if review["beer"] == beer:
                dates.append(review["date"])
        dates.pop(0)
        csv_embeddings = np.loadtxt("{}-embeddings.csv".format(beer), delimiter=",")
        row = 0
        for i in range(1, len(csv_embeddings)):
            embeddings.append(csv_embeddings[i][row])
            row += 1
 
        sim_10_percent = np.zeros((len(dates)//10, len(embeddings)))
        for i in range(len(dates)//10):
            sim_10_percent[i] = embeddings[i]
 
        sim = np.zeros((len(embeddings), len(embeddings)))
        for i in range(len(dates)):
            sim[i] = embeddings[i]
 
        y_mean_10_percent = [np.mean(sim_10_percent)]*(len(dates)//10)
        print("[{}] Mean for the first 10 percent of y values: {}".format(beer, y_mean_10_percent[0]))
        y_mean = [np.mean(sim)]*len(dates)
        y_mean_all.append(y_mean[0])
        print("[{}] Mean of all y values: {}".format(beer, y_mean[1]))
        embeddings.clear
        dates.clear
    sum_y_mean_all = 0
    for mean in y_mean_all:
        sum_y_mean_all += mean
    sum_y_mean_all = (sum_y_mean_all/len(y_mean_all))
    print("Mean of all y values for all beers: {}".format(sum_y_mean_all))
 
def countReviews(data):
    beer_names = []
 
    # make a list of all individual beers that exist in the corpus
    for review in data:
        if review["beer"] not in beer_names:
            beer_names.append(review["beer"])
            print(review["beer"])
    print("Total number of beer's found: {}".format(len(beer_names)))
 
    # calculate and save embedding in a .csv file for each beer
    for beer in beer_names:
        count = 0
        for review in data:
            if review["beer"] == beer:
                count += 1
        print("There are {} reviews for {}".format(count, beer))
 
# %%
# deploy functions
 
parseProductReviews("product_reviews.json")
countReviews(product_reviews)
calculateMean(product_reviews)
# calculateReviewEmbeddings(product_reviews, "Kiss Off", True)
# calculateReviewEmbeddingFromCsv(product_reviews, "Eiszäpfle", "Eiszäpfle-embeddings.csv", True)
# plotLineGraph(product_reviews, "Kiss Off","Kiss Off-embeddings.csv")
# generateAllEmbeddings(product_reviews)
# Out:
# India Pale Ale
# Apricot Wheat
# Barley Wine
# Full Moon
# Dunkel
# Cypress Honey Lager
# Primátor Weizenbier
# Eiszäpfle
# Hop Juice Double IPA
# Signature Pale Ale
# Hansel And Gretel
# Trader Joe's 2008 Vintage Ale
# Ballz Deep Double IPA
# Old Birdbrain
# Stegmaier Pumpkin Ale
# Vinaceous
# Ezekiel's Wheel Pale Ale
# Bandwagon
# Annularity
# Ov-ral
# Collaboration Time I
# Silk Scorpion
# Two To The Dome
# Kiss Off
# Slumbrew Yankee Swap 2013
# XHops - Green
# Vanilla Bean Assassin
# Maple Orange Imperial Caramel Cream Ale
# Bust Head English Pale Ale
# Ghost Of The 43rd
# Pumpkin Tart
# Black Ox
# St. Benedict's Breakfast
# Chronology:6
# Jerkface 9000
# Bourbon Barrel Aged Hunter
# SpontanBasil
# Groove City Hefeweizen
# Curiosity Twenty Six
# Cloudy With A Chance Of Charcuterie
# VIPA Virgindia Pale Ale
# Triangulation
# Curiosity Thirty Two
# Phaze
# New England Style IPA - Pulp Addiction
# Pillar Of Beasts
# Twisted Monkey
# Infinite Citra
# Leaves Of Grass Series III: O Captain! My Captain!
# Toasted Bock
# Total number of beer's found: 50
# There are 5379 reviews for India Pale Ale
# There are 437 reviews for Apricot Wheat
# There are 362 reviews for Barley Wine
# There are 82 reviews for Full Moon
# There are 785 reviews for Dunkel
# There are 35 reviews for Cypress Honey Lager
# There are 33 reviews for Primátor Weizenbier
# There are 65 reviews for Eiszäpfle
# There are 84 reviews for Hop Juice Double IPA
# There are 36 reviews for Signature Pale Ale
# There are 32 reviews for Hansel And Gretel
# There are 100 reviews for Trader Joe's 2008 Vintage Ale
# There are 39 reviews for Ballz Deep Double IPA
# There are 23 reviews for Old Birdbrain
# There are 31 reviews for Stegmaier Pumpkin Ale
# There are 22 reviews for Vinaceous
# There are 22 reviews for Ezekiel's Wheel Pale Ale
# There are 24 reviews for Bandwagon
# There are 30 reviews for Annularity
# There are 43 reviews for Ov-ral
# There are 37 reviews for Collaboration Time I
# There are 18 reviews for Silk Scorpion
# There are 23 reviews for Two To The Dome
# There are 15 reviews for Kiss Off
# There are 24 reviews for Slumbrew Yankee Swap 2013
# There are 13 reviews for XHops - Green
# There are 23 reviews for Vanilla Bean Assassin
# There are 14 reviews for Maple Orange Imperial Caramel Cream Ale
# There are 28 reviews for Bust Head English Pale Ale
# There are 29 reviews for Ghost Of The 43rd
# There are 22 reviews for Pumpkin Tart
# There are 32 reviews for Black Ox
# There are 21 reviews for St. Benedict's Breakfast
# There are 17 reviews for Chronology:6
# There are 30 reviews for Jerkface 9000
# There are 15 reviews for Bourbon Barrel Aged Hunter
# There are 37 reviews for SpontanBasil
# There are 31 reviews for Groove City Hefeweizen
# There are 17 reviews for Curiosity Twenty Six
# There are 32 reviews for Cloudy With A Chance Of Charcuterie
# There are 39 reviews for VIPA Virgindia Pale Ale
# There are 30 reviews for Triangulation
# There are 21 reviews for Curiosity Thirty Two
# There are 26 reviews for Phaze
# There are 29 reviews for New England Style IPA - Pulp Addiction
# There are 43 reviews for Pillar Of Beasts
# There are 46 reviews for Twisted Monkey
# There are 39 reviews for Infinite Citra
# There are 52 reviews for Leaves Of Grass Series III: O Captain! My Captain!
# There are 52 reviews for Toasted Bock
# India Pale Ale
# Apricot Wheat
# Barley Wine
# Full Moon
# Dunkel
# Cypress Honey Lager
# Primátor Weizenbier
# Eiszäpfle
# Hop Juice Double IPA
# Signature Pale Ale
# Hansel And Gretel
# Trader Joe's 2008 Vintage Ale
# Ballz Deep Double IPA
# Old Birdbrain
# Stegmaier Pumpkin Ale
# Vinaceous
# Ezekiel's Wheel Pale Ale
# Bandwagon
# Annularity
# Ov-ral
# Collaboration Time I
# Silk Scorpion
# Two To The Dome
# Kiss Off
# Slumbrew Yankee Swap 2013
# XHops - Green
# Vanilla Bean Assassin
# Maple Orange Imperial Caramel Cream Ale
# Bust Head English Pale Ale
# Ghost Of The 43rd
# Pumpkin Tart
# Black Ox
# St. Benedict's Breakfast
# Chronology:6
# Jerkface 9000
# Bourbon Barrel Aged Hunter
# SpontanBasil
# Groove City Hefeweizen
# Curiosity Twenty Six
# Cloudy With A Chance Of Charcuterie
# VIPA Virgindia Pale Ale
# Triangulation
# Curiosity Thirty Two
# Phaze
# New England Style IPA - Pulp Addiction
# Pillar Of Beasts
# Twisted Monkey
# Infinite Citra
# Leaves Of Grass Series III: O Captain! My Captain!
# Toasted Bock
# Total number of beer's found: 50
# [India Pale Ale] Mean for the first 10 percent of y values: 0.6917995895975351
# [India Pale Ale] Mean of all y values: 0.6725081678135469
# [Apricot Wheat] Mean for the first 10 percent of y values: 0.6967067503651907
# [Apricot Wheat] Mean of all y values: 0.6880749567933039
# [Barley Wine] Mean for the first 10 percent of y values: 0.5850855716400676
# [Barley Wine] Mean of all y values: 0.6460130967591938
# [Full Moon] Mean for the first 10 percent of y values: 0.7459195926785469
# [Full Moon] Mean of all y values: 0.6844866871833801
# [Dunkel] Mean for the first 10 percent of y values: 0.6434049510802978
# [Dunkel] Mean of all y values: 0.6025100305946116
# [Cypress Honey Lager] Mean for the first 10 percent of y values: 0.7384483416875204
# [Cypress Honey Lager] Mean of all y values: 0.6022254066432223
# [Primátor Weizenbier] Mean for the first 10 percent of y values: 0.6380171577135721
# [Primátor Weizenbier] Mean of all y values: 0.596394055057317
# [Eiszäpfle] Mean for the first 10 percent of y values: 0.57363793750604
# [Eiszäpfle] Mean of all y values: 0.5911282645538449
# [Hop Juice Double IPA] Mean for the first 10 percent of y values: 0.6926180273294449
# [Hop Juice Double IPA] Mean of all y values: 0.6816028406821102
# [Signature Pale Ale] Mean for the first 10 percent of y values: 0.6319860021273295
# [Signature Pale Ale] Mean of all y values: 0.6192343243530818
# [Hansel And Gretel] Mean for the first 10 percent of y values: 0.7654930353164673
# [Hansel And Gretel] Mean of all y values: 0.7202648731970018
# [Trader Joe's 2008 Vintage Ale] Mean for the first 10 percent of y values: 0.666060573524899
# [Trader Joe's 2008 Vintage Ale] Mean of all y values: 0.6769393044288712
# [Ballz Deep Double IPA] Mean for the first 10 percent of y values: 0.6527148485183716
# [Ballz Deep Double IPA] Mean of all y values: 0.6258545392437985
# [Old Birdbrain] Mean for the first 10 percent of y values: 0.7075415253639221
# [Old Birdbrain] Mean of all y values: 0.6980436986142938
# [Stegmaier Pumpkin Ale] Mean for the first 10 percent of y values: 0.6268376111984253
# [Stegmaier Pumpkin Ale] Mean of all y values: 0.6932568311691284
# [Vinaceous] Mean for the first 10 percent of y values: 0.6925508081912994
# [Vinaceous] Mean of all y values: 0.5915536234776179
# [Ezekiel's Wheel Pale Ale] Mean for the first 10 percent of y values: 0.6868157088756561
# [Ezekiel's Wheel Pale Ale] Mean of all y values: 0.5697368525323414
# [Bandwagon] Mean for the first 10 percent of y values: 0.7548176646232605
# [Bandwagon] Mean of all y values: 0.6627613085767498
# [Annularity] Mean for the first 10 percent of y values: 0.6388140320777893
# [Annularity] Mean of all y values: 0.6500653305958057
# [Ov-ral] Mean for the first 10 percent of y values: 0.6945973783731461
# [Ov-ral] Mean of all y values: 0.6456771659709158
# [Collaboration Time I] Mean for the first 10 percent of y values: 0.6904511451721191
# [Collaboration Time I] Mean of all y values: 0.727015377746688
# [Silk Scorpion] Mean for the first 10 percent of y values: 0.7392780780792236
# [Silk Scorpion] Mean of all y values: 0.593617682947832
# [Two To The Dome] Mean for the first 10 percent of y values: 0.7179009318351746
# [Two To The Dome] Mean of all y values: 0.673308097503402
# [Kiss Off] Mean for the first 10 percent of y values: 0.6256827116012573
# [Kiss Off] Mean of all y values: 0.5581042500478881
# [Slumbrew Yankee Swap 2013] Mean for the first 10 percent of y values: 0.7830776572227478
# [Slumbrew Yankee Swap 2013] Mean of all y values: 0.7057195189206497
# [XHops - Green] Mean for the first 10 percent of y values: 0.7055314183235168
# [XHops - Green] Mean of all y values: 0.6389414196213087
# [Vanilla Bean Assassin] Mean for the first 10 percent of y values: 0.6151241660118103
# [Vanilla Bean Assassin] Mean of all y values: 0.500998158346523
# [Maple Orange Imperial Caramel Cream Ale] Mean for the first 10 percent of y values: 0.6668989658355713
# [Maple Orange Imperial Caramel Cream Ale] Mean of all y values: 0.6537580535962031
# [Bust Head English Pale Ale] Mean for the first 10 percent of y values: 0.6743066906929016
# [Bust Head English Pale Ale] Mean of all y values: 0.6094414073008078
# [Ghost Of The 43rd] Mean for the first 10 percent of y values: 0.2790224701166153
# [Ghost Of The 43rd] Mean of all y values: 0.5768256410956383
# [Pumpkin Tart] Mean for the first 10 percent of y values: 0.8302759528160095
# [Pumpkin Tart] Mean of all y values: 0.7537779495829627
# [Black Ox] Mean for the first 10 percent of y values: 0.6828164458274841
# [Black Ox] Mean of all y values: 0.6104459647209414
# [St. Benedict's Breakfast] Mean for the first 10 percent of y values: 0.8145375847816467
# [St. Benedict's Breakfast] Mean of all y values: 0.6372714713215828
# [Chronology:6] Mean for the first 10 percent of y values: 0.32981544733047485
# [Chronology:6] Mean of all y values: 0.6032455340027809
# [Jerkface 9000] Mean for the first 10 percent of y values: 0.5707405805587769
# [Jerkface 9000] Mean of all y values: 0.5906439187197849
# [Bourbon Barrel Aged Hunter] Mean for the first 10 percent of y values: 0.5517442226409912
# [Bourbon Barrel Aged Hunter] Mean of all y values: 0.591736444405147
# [SpontanBasil] Mean for the first 10 percent of y values: 0.5680240194002787
# [SpontanBasil] Mean of all y values: 0.6588149633672502
# [Groove City Hefeweizen] Mean for the first 10 percent of y values: 0.3710516591866811
# [Groove City Hefeweizen] Mean of all y values: 0.568830664952596
# [Curiosity Twenty Six] Mean for the first 10 percent of y values: 0.6977883577346802
# [Curiosity Twenty Six] Mean of all y values: 0.6619100421667099
# [Cloudy With A Chance Of Charcuterie] Mean for the first 10 percent of y values: 0.6542341113090515
# [Cloudy With A Chance Of Charcuterie] Mean of all y values: 0.578040161921132
# [VIPA Virgindia Pale Ale] Mean for the first 10 percent of y values: 0.5353526920080185
# [VIPA Virgindia Pale Ale] Mean of all y values: 0.6199709973052928
# [Triangulation] Mean for the first 10 percent of y values: 0.6477441787719727
# [Triangulation] Mean of all y values: 0.6076149165887257
# [Curiosity Thirty Two] Mean for the first 10 percent of y values: 0.67555832862854
# [Curiosity Thirty Two] Mean of all y values: 0.5687410071492195
# [Phaze] Mean for the first 10 percent of y values: 0.6203461289405823
# [Phaze] Mean of all y values: 0.5483363962173462
# [New England Style IPA - Pulp Addiction] Mean for the first 10 percent of y values: 0.3248548358678818
# [New England Style IPA - Pulp Addiction] Mean of all y values: 0.5586449078151158
# [Pillar Of Beasts] Mean for the first 10 percent of y values: 0.6031906008720398
# [Pillar Of Beasts] Mean of all y values: 0.6554418404897054
# [Twisted Monkey] Mean for the first 10 percent of y values: 0.41570334136486053
# [Twisted Monkey] Mean of all y values: 0.5887836916579141
# [Infinite Citra] Mean for the first 10 percent of y values: 0.6816637516021729
# [Infinite Citra] Mean of all y values: 0.5462817635975385
# [Leaves Of Grass Series III: O Captain! My Captain!] Mean for the first 10 percent of y values: 0.48876901865005495
# [Leaves Of Grass Series III: O Captain! My Captain!] Mean of all y values: 0.6081457208184635
# [Toasted Bock] Mean for the first 10 percent of y values: 0.6495427846908569
# [Toasted Bock] Mean of all y values: 0.584500197686401
# Mean of all y values for all beers: 0.6259447903970736
